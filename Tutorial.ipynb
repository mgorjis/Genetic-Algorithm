# %%
# %reset

# %%
import sys
sys.path.insert(0, './src')

import numpy as np
from DC import DeterCrowd
from utils import *
import sympy
import matplotlib.pyplot as plt
# %matplotlib inline


#%autoreload 2

# %%
#Function='sin(x1)*sin(x2)'
#ListOfVars=['x1','x2']
#R=np.array([[-np.pi,np.pi],[-np.pi,np.pi]])

Function='sin(5*x1)*cos(10*x1)'
ListOfVars=['x1']
R=np.array([[-np.pi,np.pi]])

#Function='sin(x1)*cos(x2)*log(x3)'
#ListOfVars=['x1','x2','x3']
#R=np.array([[-1,1],[-1,1],[2,4]])

NumGen=5000
PopSize=50


#Function='x1^2'
#ListOfVars=['x1']
#R=np.array([[-1,1]])
#NumGen=5000
#PopSize=50

# %%
MinFit,MaxFit, AverageFit,a,b,n =DeterCrowd(Function,ListOfVars,R,NumGen,PopSize)
# Out:
# The minimim of function   sin(5*x1)*cos(10*x1)  is  -0.999999985028 occured in   [-0.9424932733967034]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

t = np.arange(0.0, NumGen, 1)

plt.plot(t,MinFit[0,:])
#plt.plot(t,MaxFit[0,:])
#plt.plot(t,AverageFit[0,:])

# %%
# -----------------------------

# %%
from DCRW import DCRW
MinFit,MaxFit, AverageFit,a,b,n =DCRW(Function,ListOfVars,R,NumGen,PopSize)
# Out:
# The minimim of function   sin(5*x1)*cos(10*x1)  is  -0.999999725357 occured in   [0.31422555481767234]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

t = np.arange(0.0, NumGen, 1)

plt.plot(t,MinFit[0,:])
#plt.plot(t,MaxFit[0,:])
#plt.plot(t,AverageFit[0,:])
